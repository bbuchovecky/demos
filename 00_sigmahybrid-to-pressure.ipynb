# %%
import xarray as xr

# %%
ds = xr.open_dataset('/glade/work/bbuchovecky/plev_interp_T.nc')

# %%
ds['T'].lev_p
# Out:
# <xarray.DataArray 'lev_p' (lev_p: 15)>
# array([1000.,  925.,  850.,  700.,  600.,  500.,  250.,  150.,  100.,   70.,
#          50.,   20.,   10.,    5.,    1.], dtype=float32)
# Coordinates:
#   * lev_p    (lev_p) float32 1e+03 925.0 850.0 700.0 600.0 ... 20.0 10.0 5.0 1.0

# %%
(ds['T'].isel(time=0, lev_p=5)-273.15).plot()

# %%
ps = xr.open_dataset('/glade/derecho/scratch/bbuchovecky/archive/COUP0000_PI_SOM/atm/hist/COUP0000_PI_SOM.cam.h0.0049-01.nc')['PS']

# %%
(ps/100).plot()
